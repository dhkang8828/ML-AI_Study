# %%
import matplotlib.pyplot as plt
import numpy as np

# 간단한 sin 함수 그래프
x = np.linspace(0, 2*np.pi, 100)
y = np.sin(x)

plt.figure(figsize=(10, 6))
plt.plot(x, y, 'b-', linewidth=2, label='sin(x)')
plt.xlabel('x')
plt.ylabel('y')
plt.title('Simple Sine Wave')
plt.grid(True, alpha=0.3)
plt.legend()
plt.show()

# %% [markdown]
# # Summation

# %%
n = int(input("enter number: "))
x = [i  + 1 for i in range(n)]

ret = 0
for x_i in x:
    ret += x_i
print(f"Summation of numbers:{ret}")
# Out:
# Summation of numbers:55

# %% [markdown]
# # ARGMAX

# %%
import numpy as np
X = [i + 1 for i in range(10)]

def f(x):
    return -np.log(x)

max_val = -np.inf
argmax = None
for x in X:
    val = f(x)
    if val > max_val:
        max_val = val
        argmax = x
        
print(f"argmax: {argmax}, max value: {max_val}")
# Out:
# argmax: 1, max value: -0.0

# %%
import torch
import torch.nn as nn
import torch.optim as optim
import numpy as np

# %%
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu')
print(f"Using device: {device}")
# Out:
# Using device: cuda

# %%
## 간단한 데이터 생성
X = torch.randn(1000, 20).to(device)
y = torch.randn(1000, 1).to(device)
# 간단한 신경망 정의
class SimpleNet(nn.Module):
    def __init__(self):
        super(SimpleNet, self).__init__()
        self.fc1 = nn.Linear(20, 64)
        self.fc2 = nn.Linear(64, 32)
        self.fc3 = nn.Linear(32, 1)
        self.relu = nn.ReLU()

    def forward(self, x):
        x = self.relu(self.fc1(x))
        x = self.relu(self.fc2(x))
        x = self.fc3(x)
        return x

# 모델을 GPU로 이동
model = SimpleNet().to(device)
print(f"Model parameters are on: {next(model.parameters()).device}")

##손실 함수와 옵티마이저
criterion = nn.MSELoss()
optimizer = optim.Adam(model.parameters(),lr=0.001)

# 간단한 학습 루프
print("\nTraining...")
for epoch in range(100):
    optimizer.zero_grad()
    outputs = model(X)
    loss = criterion(outputs, y)
    loss.backward()
    optimizer.step()

    if epoch % 20 == 0:
        print(f'Epoch [{epoch}/100], Loss: {loss.item():.4f}')

print("\nTraining completed!")
# Out:
# Model parameters are on: cuda:0
#
# Training...
# Epoch [0/100], Loss: 0.9534
# Epoch [20/100], Loss: 0.8874
# Epoch [40/100], Loss: 0.8311
# Epoch [60/100], Loss: 0.7600
# Epoch [80/100], Loss: 0.6684
#
# Training completed!
